# %%
import pandas as pd
import numpy as np
df = pd.read_csv('data.csv')
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# Data Cleaning: Data cleaning means fixing bad data in your data set.
# Bad data could be:
# 1. Empty cells -- Remove row with empty cell
# 2. Data in wrong format -- like date in the dataframe shown above
# 3. Wrong data -- value should be "45" instead of "450", and we could just insert "45" in row 7, can be corrected or delete the row with wrong data
# 4. Duplicates -- Removes the duplicates

# %%
#Drop rows with empty data
df = df.dropna()
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
#Data in wrong format -- like date in the dataframe shown above
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
#value should be "45" instead of "450", and we could just insert "45" in row 7:
df.loc[7, 'Duration'] = 45

# %%
#################################################Try by students 
#Delete rows where "Duration" is higher than 120:

#for x in df.index:
#  if df.loc[x, "Duration"] > 120:
#    df.drop(x, inplace = True)

# %%
# Removes duplicates like row 11 and 12
df = df.drop_duplicates()
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         45 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# ...

# %% [markdown]
# Given two arrays, arr_1 = np.array([1, 2, 3, 4]), arr_2 = np.array([2, 4, 6, 8]). Print the
# results of the following operations: Add, Subtract, Multiply, Divide.
#
# Use NumPy
# A. Generate a random integer 2D array with three rows and four columns named
# arr_3, with four values between 0 and 100.
# B. print the exponential and logarithmic values of all elements in array arr_1.
# C. Given an array arr_4 = np.array(1.2, 2.5, 5.6, 3.4, 7.8], print the round-down
# (floor) and round-up (ceil) values.

# %%
arr_1 = np.array([1, 2, 3, 4])
arr_2 = np.array([2, 4, 6, 8])

# %%
arr_3 = arr_1 + arr_2
arr_3
# Out:
# array([ 3,  6,  9, 12])

# %%
arr_3 = arr_1 - arr_2
arr_3
# Out:
# array([-1, -2, -3, -4])

# %%
arr_3 = arr_1 * arr_2
arr_3
# Out:
# array([ 2,  8, 18, 32])

# %%
arr_3 = arr_1 / arr_2
arr_3
# Out:
# array([0.5, 0.5, 0.5, 0.5])

# %%
arr_3 = np.random.randint(0, 101, size=(3, 4))
#Random 2D Array (arr_3)
print(arr_3)
# Out:
# [[97 16 89 88]
#  [88 10 74 45]
#  [12 72 16 10]]

# %%
np.log(arr_1)
# Out:
# array([0.        , 0.69314718, 1.09861229, 1.38629436])

# %%
np.exp(arr_1)
# Out:
# array([ 2.71828183,  7.3890561 , 20.08553692, 54.59815003])

# %%
arr_4 = np.array([1.2, 2.5, 5.6, 3.4, 7.8])

# %%
np.ceil(arr_4)
# Out:
# array([2., 3., 6., 4., 8.])

# %%
np.floor(arr_4)
# Out:
# array([1., 2., 5., 3., 7.])

# %% [markdown]
# Question 3 Generate an array of 200 values between -pi & pi. Calculate the corresponding sin, cos
# and tan value for the generated array. Finally, plot the sin, cos and tan curves using the
# matplotlib library.
# Hints: use np.linspace to generate values (gen_arr), then sin_values = np.sin(gen_arr)
# and so on for others and finally use plot(gen_arr, sin_values). Follow the same for cos
# and tan also.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate array of 200 values between -pi and pi
gen_arr = np.linspace(-np.pi, np.pi, 200)

# Calculate sin, cos, and tan values for the generated array
sin_values = np.sin(gen_arr)
cos_values = np.cos(gen_arr)
tan_values = np.tan(gen_arr)

plt.plot(gen_arr, sin_values, label='sin(x)')
plt.plot(gen_arr, cos_values, label='cos(x)')
plt.plot(gen_arr, tan_values, label='tan(x)')

plt.xlabel('x')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
gen_arr
# Out:
# array([-3.14159265, -3.11001886, -3.07844506, -3.04687127, -3.01529747,
#        -2.98372368, -2.95214988, -2.92057608, -2.88900229, -2.85742849,
#        -2.8258547 , -2.7942809 , -2.76270711, -2.73113331, -2.69955952,
#        -2.66798572, -2.63641193, -2.60483813, -2.57326433, -2.54169054,
#        -2.51011674, -2.47854295, -2.44696915, -2.41539536, -2.38382156,
#        -2.35224777, -2.32067397, -2.28910017, -2.25752638, -2.22595258,
#        -2.19437879, -2.16280499, -2.1312312 , -2.0996574 , -2.06808361,
#        -2.03650981, -2.00493602, -1.97336222, -1.94178842, -1.91021463,
#        -1.87864083, -1.84706704, -1.81549324, -1.78391945, -1.75234565,
#        -1.72077186, -1.68919806, -1.65762426, -1.62605047, -1.59447667,
#        -1.56290288, -1.53132908, -1.49975529, -1.46818149, -1.4366077 ,
#        -1.4050339 , -1.3734601 , -1.34188631, -1.31031251, -1.27873872,
#        -1.24716492, -1.21559113, -1.18401733, -1.15244354, -1.12086974,
# ...

# %% [markdown]
# Question 3. Given two 2D arrays, arr_1 = np.array([[1, 2], [3, 4]]), arr_2 = np.array([[2, 4], [6, 9]]).
# Perform the following operations.
# A. Matrix multiplication with Dot Product
# B. Compute eigenvalues and eigenvectors for both matrices.
# C. Compute the determinant of both matrices.
# D. Compute the inverse of both the matrices.
# Hint: Use from numpy import linalg as LA

# %%
arr_1 = np.array([[1, 2], [3, 4]])
arr_2 = np.array([[2, 4], [6, 9]])

# %%
from numpy import linalg as LA

# %%
matrix_product = np.dot(arr_1, arr_2)
matrix_product
# Out:
# array([[14, 22],
#        [30, 48]])

# %%
eigenvalues_1, eigenvectors_1 = LA.eig(arr_1)
eigenvalues_1, eigenvectors_1
# Out:
# (array([-0.37228132,  5.37228132]),
#  array([[-0.82456484, -0.41597356],
#         [ 0.56576746, -0.90937671]]))

# %%
eigenvalues_2, eigenvectors_2 = LA.eig(arr_2)
eigenvalues_2, eigenvectors_2
# Out:
# (array([-0.52079729, 11.52079729]),
#  array([[-0.84601546, -0.38733662],
#         [ 0.53315837, -0.92193836]]))

# %%
determinant_1 = LA.det(arr_1)
determinant_1
# Out:
# -2.0000000000000004

# %%
determinant_2 = LA.det(arr_2)
determinant_2
# Out:
# -6.0

# %%
inverse_1 = LA.inv(arr_1)
inverse_1
# Out:
# array([[-2. ,  1. ],
#        [ 1.5, -0.5]])

# %%
inverse_2 = LA.inv(arr_2)
inverse_2
# Out:
# array([[-1.5       ,  0.66666667],
#        [ 1.        , -0.33333333]])

# %% [markdown]
# #Question 5: Using the given data, use the matplotlib library to draw the Pie chart for the column class.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/mpg_ggplot2.csv')

# %%
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
df['class']
# Out:
# 0      compact
# 1      compact
# 2      compact
# 3      compact
# 4      compact
#         ...
# 229    midsize
# 230    midsize
# 231    midsize
# 232    midsize
# 233    midsize
# Name: class, Length: 234, dtype: object

# %%
unique_counts = df['class'].value_counts()
unique_counts
# Out:
# suv           62
# compact       47
# midsize       41
# subcompact    35
# pickup        33
# minivan       11
# 2seater        5
# Name: class, dtype: int64

# %%
import matplotlib.pyplot as plt 

plt.pie(df['class'].value_counts().tolist(),labels=df['class'].value_counts().index.tolist())
plt.show()

# %%
import seaborn as sns 
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris)

# %% [markdown]
# Download the given dataset and plot the histogram for integer and float columns of the
# dataset.

# %%
df = pd.read_csv('ComputerSales.csv')

# %%
df
# Out:
#     Sale ID          Contact Sex  Age State Product ID Product Type  \
# 0         1      Paul Thomas   M   43    OH  M01-F0024      Desktop
# 1         2      Margo Simms   F   37    WV  GT13-0024      Desktop
# 2         3        Sam Stine   M   26    PA      I3670      Desktop
# 3         4       Moe Eggert   M   35    PA      I3593       Laptop
# 4         5      Jessica Elk   F   55    PA     15M-ED       Laptop
# 5         6  Sally Struthers   F   45    PA  GT13-0024      Desktop
# 6         7   Michelle Samms   F   46    OH    GA401IV       Laptop
# 7         8     Mick Roberts   M   23    OH    MY2J2LL       Tablet
# 8         9      Ed Klondike   M   52    OH     81TC00       Laptop
# 9        10       Phil Jones   M   56    WV  M01-F0024      Desktop
# 10       11       Rick James   M   49    PA    GA401IV       Laptop
# 11       12         Sue Etna   F   54    OH  GT13-0024      Desktop
# 12       13       Jason Case   M   57    PA     81TC00       Laptop
# ...

# %%
np.array(df.Age)
# Out:
# array([43, 37, 26, 35, 55, 45, 46, 23, 52, 56, 49, 54, 57, 51, 56, 49, 46,
#        46, 23, 45, 57, 51, 43, 37, 46, 23, 52, 35, 55, 56, 49, 54, 49, 46,
#        46, 45, 57, 51, 35], dtype=int64)

# %%
plt.hist(np.array(df.Age),[0,10,20,30,40,50,60,70,80])
plt.show()

# %%
plt.hist(np.array(df['Sale Price']),[0,500,1000,1500,2000])
plt.show()

# %%
Download the dataset and plot the scatter plot for the sale price and profit columns.

# %%
plt.scatter(np.array(df['Sale Price']),np.array(df['Profit']))
plt.show()

# %% [markdown]
# Download the given dataset and split the dataset into 70% for training and 30% for
# testing using the Scikit library.

# %%
df = pd.read_csv('Housing.csv')

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
x=df.drop(columns='area')

# %%
x
# Out:
#         price  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000         4          2        3      yes        no       no
# 1    12250000         4          4        4      yes        no       no
# 2    12250000         3          2        2      yes        no      yes
# 3    12215000         4          2        2      yes        no      yes
# 4    11410000         4          1        2      yes       yes      yes
# ..        ...       ...        ...      ...      ...       ...      ...
# 540   1820000         2          1        1      yes        no      yes
# 541   1767150         3          1        1       no        no       no
# 542   1750000         2          1        1      yes        no       no
# 543   1750000         3          1        1       no        no       no
# 544   1750000         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
y=df.price

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
x_train.shape
# Out:
# (381, 12)

# %% [markdown]
# Download the dataset given in the link, convert the categorical data into integer columns,
# and print the shape and head of the dataset

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df_encoded = df.apply(label_encoder.fit_transform)

# Printing the shape and head of the dataset
print("Shape of the dataset:", df_encoded.shape)
print("\nHead of the dataset:")
print(df_encoded.head())
# Out:
# Shape of the dataset: (545, 13)
#
# Head of the dataset:
#    price  area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    218   232         3          1        2         1          0         0
# 1    217   260         3          3        3         1          0         0
# 2    217   268         2          1        1         1          0         1
# 3    216   237         3          1        1         1          0         1
# 4    215   232         3          0        1         1          1         1
#
#    hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# 0                0                1        2         1                 0
# 1                0                1        3         0                 0
# 2                0                0        2         1                 1
# 3                0                1        3         1                 0
# 4                0                1        2         0                 0
